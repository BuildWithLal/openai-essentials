# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os
import IPython
from openai import OpenAI

# %%
client = OpenAI()

# %% [markdown]
# ### Transcriptions

# %%
# !ls -l
# Out:
# total 60
# -rw-rw-r-- 1 lal lal  1479 Jul 29 18:44 openai-whisper.ipynb
# -rw-rw-r-- 1 lal lal 56160 Jul 24 00:17 speech.mp3

# %%
IPython.display.Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_file = open("speech.mp3", "rb")

# %%
transcription = client.audio.transcriptions.create(
  model="whisper-1", 
  file=audio_file    
)

# %%
print(transcription)
# Out:
# Transcription(text='OpenAI is great for turning text into speech.')

# %%
print(transcription.text)
# Out:
# OpenAI is great for turning text into speech.

# %%
# !ls -l
# Out:
# total 216
# -rw-rw-r-- 1 lal lal 79680 Jul 29 00:25 german.mp3
# -rw-rw-r-- 1 lal lal 79239 Jul 29 18:50 openai-whisper.ipynb
# -rw-rw-r-- 1 lal lal 56160 Jul 24 00:17 speech.mp3

# %%
audio_file = open("german.mp3", "rb")

# %%
transcription = client.audio.transcriptions.create(
  model="whisper-1", 
  file=audio_file    
)

# %%
print(transcription)
# Out:
# Transcription(text='OpenAI eignet sich hervorragend, um Text in Sprache umzuwandeln.')

# %%
IPython.display.Audio("german.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Translations

# %% [markdown]
# #### German to English

# %%
audio_file = open("german.mp3", "rb")

# %%
translation = client.audio.translations.create(
  model="whisper-1", 
  file=audio_file,
)

# %%
print(translation.text)
# Out:
# OpenAI is perfect for converting text into language.
